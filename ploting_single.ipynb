# %%
import ast
import pandas as pd
import matplotlib
import matplotlib.font_manager as fm
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

import modules.quantizing as quant
from modules.ploting import confusion_matrix_plot, build_data

# %% [markdown]
# Parameters for clean figure export

# %%
fm.fontManager.addfont("modules/cmunss.ttf")
plt.rcParams['font.family'] = 'CMU Sans Serif'
plt.rcParams['svg.fonttype'] = 'none'

font = {'family' : 'CMU Sans Serif',
        'size'   : 11}

matplotlib.rc('font', **font)

# %% [markdown]
# ### Parameters

# %% [markdown]
# Dimension, à choisir parmi ["familiarité", "agréabilité", "utilité", "légitimité"]

# %%
DIM = "utilité"

# %%
folder_name = "model-name"

# %%
threshold_classification = 2/6-0.01
threshold_evaluation = 2/6-0.01

# %% [markdown]
# ### Corpus parsing

# %%
predictions = build_data(folder_name, DIM)

# %%
#Première ligne du dataframe pour exemple
print(predictions.iloc[0])
# Out:
# id                              0
# text          Ceci est un exemple
# utilité           [0.0, 1.0, 0.0]
# prediction        [0.0, 1.0, 0.0]
# Name: 0, dtype: object

# %% [markdown]
# ### Multi-class confusion matrix

# %%
label_gold = np.array(list(predictions[DIM]))
label_pred = np.array(list(predictions["prediction"]))

confusion_matrix_plot(label_gold,
                      label_pred,
                      # "savename")
                      )
